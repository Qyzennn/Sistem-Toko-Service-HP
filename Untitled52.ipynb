# %%
print(df.columns)
# Out:
# Index(['user_id', 'failed_login_attempts', 'account_age_days',
#        'login_attempts_last_7days', 'unique_ip_addresses',
#        'failed_2fa_attempts', 'account_status', 'last_login_days_ago',
#        'account_compromise_risk'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# =====================
# BACA DATASET
# =====================

df = pd.read_csv("authentication_failures_dataset.csv")

# tampilkan nama kolom
print("NAMA KOLOM:")
print(df.columns)

# =====================
# AMBIL 2 KOLOM PERTAMA
# =====================

X = df.iloc[:, [0]]
y = df.iloc[:, 1]

# =====================
# REGRESI
# =====================

model = LinearRegression()
model.fit(X, y)

y_pred = model.predict(X)

# =====================
# EVALUASI
# =====================

r2 = r2_score(y, y_pred)
rmse = np.sqrt(mean_squared_error(y, y_pred))

print("\nR2:", r2)
print("RMSE:", rmse)

# =====================
# VISUALISASI
# =====================

plt.figure(figsize=(8,5))

plt.scatter(X, y)
plt.plot(X, y_pred)

plt.xlabel(df.columns[0])
plt.ylabel(df.columns[1])

plt.title("Regresi Linear")

plt.show()
# Out:
# NAMA KOLOM:
# Index(['user_id', 'failed_login_attempts', 'account_age_days',
#        'login_attempts_last_7days', 'unique_ip_addresses',
#        'failed_2fa_attempts', 'account_status', 'last_login_days_ago',
#        'account_compromise_risk'],
#       dtype='object')
#
# R2: 0.0021316590696511817
# RMSE: 6.023248560373785
